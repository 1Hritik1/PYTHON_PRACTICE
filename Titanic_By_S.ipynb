# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("/content/titanic.csv")

# %%
data
# Out:
#       pclass  survived  ...      fare embarked
# 0          1         1  ...  211.3375        S
# 1          1         0  ...  151.5500        S
# 2          1         0  ...  151.5500        S
# 3          1         0  ...  151.5500        S
# 4          1         1  ...   26.5500        S
# ...      ...       ...  ...       ...      ...
# 1252       3         0  ...    9.5000        S
# 1253       3         0  ...   14.4542        C
# 1254       3         1  ...   14.4542        C
# 1255       3         0  ...    7.2250        C
# 1256       3         0  ...    7.2250        C
#
# [1257 rows x 9 columns]

# %%
data["PassengerID"]=np.arange(len(data))

# %%
data.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'PassengerID'],
#       dtype='object')

# %%
data.PassengerID
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 1252    1252
# 1253    1253
# 1254    1254
# 1255    1255
# 1256    1256
# Name: PassengerID, Length: 1257, dtype: int64

# %%
data.groupby('survived')['PassengerID'].count()
# Out:
# survived
# 0    776
# 1    481
# Name: PassengerID, dtype: int64

# %%
f, ax = plt.subplots(figsize=(11,5))
sns.boxplot(x='survived', y='age', data=data)

# %%
f, ax = plt.subplots(figsize=(10,8))
sns.boxplot(x='sex',y='survived',data=data)

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.boxplot(x='sex', y='age', hue='survived', data=data)

# %%
sns.barplot(x='pclass', y='survived', data=data)

# %%
sns.barplot(x='pclass', y='survived', hue='sex', data=data)

# %%
df=data[data.survived==1]

# %%
df[df.sex=='male']
# Out:
#       pclass  survived  ... embarked PassengerID
# 4          1         1  ...        S           4
# 16         1         1  ...        S          16
# 18         1         1  ...        C          18
# 22         1         1  ...        C          22
# 25         1         1  ...        S          25
# ...      ...       ...  ...      ...         ...
# 1192       3         1  ...        S        1192
# 1194       3         1  ...        S        1194
# 1209       3         1  ...        S        1209
# 1211       3         1  ...        C        1211
# 1231       3         1  ...        C        1231
#
# [153 rows x 10 columns]

# %%
sns.barplot(x='sibsp', y='survived', data=data)

# %%
survived = data.loc[data['survived']==1,"age"].dropna()
sns.distplot(survived)
plt.title("Survived")
# Out:
# Text(0.5, 1.0, 'Survived')

# %%
sns.pairplot(data.dropna())
